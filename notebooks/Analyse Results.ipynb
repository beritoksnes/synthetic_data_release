# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

from warnings import filterwarnings
filterwarnings('ignore')

# %%
import sys
sys.path.append('../')

from utils.analyse_results import *

# %% [markdown]
# # Linkage

# %%
dirname = '../tests/linkage/'
linkage_gain = load_results_linkage(dirname)

# %%
models = ['BayesianNet', 'PrivBayesEps1.0']
fig = plt_per_target_pg(linkage_gain, models, resFilter=('FeatureSet', 'Correlations'))

# %% [markdown]
# # Inference

# %%
dirname = '../tests/inference/'
dpath = '../data/texas'
inference_gain = load_results_inference(dirname, dpath)

# %%
inference_gain
# Out:
#     Dataset TargetID SensitiveAttribute Run      TargetModel  \
# 0     texas  ID14086       LengthOfStay   0      BayesianNet
# 1     texas  ID14086       LengthOfStay   0  PrivBayesEps1.0
# 2     texas  ID14086       LengthOfStay   0              Raw
# 3     texas  ID14086       LengthOfStay   1      BayesianNet
# 4     texas  ID14086       LengthOfStay   1  PrivBayesEps1.0
# ..      ...      ...                ...  ..              ...
# 145   texas  ID31432               RACE   3  PrivBayesEps1.0
# 146   texas  ID31432               RACE   3              Raw
# 147   texas  ID31432               RACE   4      BayesianNet
# 148   texas  ID31432               RACE   4  PrivBayesEps1.0
# 149   texas  ID31432               RACE   4              Raw
#
#      ProbCorrectRawIn  ProbCorrectRawOut  AdvantageRaw  ProbCorrectSynIn  \
# 0       8.269030e-263      8.269030e-263           0.0      3.248841e-03
# 1       8.269030e-263      8.269030e-263           0.0      1.340829e-03
# 2       8.269030e-263      8.269030e-263           0.0     8.269030e-263
# 3       1.357431e-172      1.357431e-172           0.0      7.915682e-03
# 4       1.357431e-172      1.357431e-172           0.0      1.231935e-03
# ..                ...                ...           ...               ...
# 145      0.000000e+00       0.000000e+00           0.0      4.000000e-01
# 146      0.000000e+00       0.000000e+00           0.0      0.000000e+00
# 147      0.000000e+00       0.000000e+00           0.0      3.000000e-01
# 148      0.000000e+00       0.000000e+00           0.0      0.000000e+00
# 149      0.000000e+00       0.000000e+00           0.0      0.000000e+00
#
#      ProbCorrectSynOut  AdvantageSyn  PrivacyGain
# 0         1.638911e-57      0.003249    -0.003249
# 1         1.215110e-03      0.000126    -0.000126
# 2        8.269030e-263      0.000000     0.000000
# 3         1.197732e-73      0.007916    -0.007916
# 4         8.285036e-04      0.000403    -0.000403
# ..                 ...           ...          ...
# 145       0.000000e+00      0.400000    -0.400000
# 146       0.000000e+00      0.000000     0.000000
# 147       2.000000e-01      0.100000    -0.100000
# 148       1.000000e-01     -0.100000     0.100000
# 149       0.000000e+00      0.000000     0.000000
#
# [150 rows x 12 columns]

# %%
models = ['BayesianNet', 'PrivBayesEps1.0']
fig = plt_per_target_pg(inference_gain, models, resFilter=('SensitiveAttribute', 'RACE'))

# %% [markdown]
# # Aggregate Utility

# %%
dirname = '../tests/utility/'
utility_record, utility_agg = load_results_utility(dirname)

# %%
labelVar = 'RiskMortality'
models = ['Raw', 'BayesianNet', 'PrivBayesEps1.0']
fig = plt_avg_accuracy(utility_agg, models)
