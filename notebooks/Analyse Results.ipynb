# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

from warnings import filterwarnings
filterwarnings('ignore')

# %%
import sys
sys.path.append('../')

from utils.analyse_results import *

# %% [markdown]
# # Linkage

# %%
dirname = '../tests_support2_small/linkage/'
linkage_gain = load_results_linkage(dirname)

# %%
linkage_gain.TargetModel.unique()
# Out:
# array(['CTGAN', 'Cvine', 'PrivBayesEps0.1', 'TVAE'], dtype=object)

# %%
models = ['Cvine', 'PrivBayesEps0.1', 'CTGAN', 'TVAE']
fig = plt_per_target_pg(linkage_gain, models, resFilter=('FeatureSet', 'Correlations'))

# %% [markdown]
# # Inference

# %%
dirname = '../tests_support2_small/inference/'
dpath = '../data/support2/real_support2_small'
inference_gain = load_results_inference(dirname, dpath)

# %%
inference_gain
# Out:
#     Dataset TargetID SensitiveAttribute Run      TargetModel  \
# 0     small   ID1124               crea   0            CTGAN
# 1     small   ID1124               crea   0            Cvine
# 2     small   ID1124               crea   0  PrivBayesEps0.1
# 3     small   ID1124               crea   0              Raw
# 4     small   ID1124               crea   0             TVAE
# ..      ...      ...                ...  ..              ...
# 145   small     ID84             totcst   4            CTGAN
# 146   small     ID84             totcst   4            Cvine
# 147   small     ID84             totcst   4  PrivBayesEps0.1
# 148   small     ID84             totcst   4              Raw
# 149   small     ID84             totcst   4             TVAE
#
#      ProbCorrectRawIn  ProbCorrectRawOut  AdvantageRaw  ProbCorrectSynIn  \
# 0        4.234145e-33       4.234145e-33           0.0      7.859144e-02
# 1        4.234145e-33       4.234145e-33           0.0      2.615825e-02
# ...

# %%
models = ['Cvine', 'PrivBayesEps0.1', 'CTGAN', 'TVAE']
fig = plt_per_target_pg(inference_gain, models, resFilter=('SensitiveAttribute', 'crea'))
